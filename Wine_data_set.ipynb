# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandhiya-B26/DEV-assignment/blob/main/Wine_data_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import plotly.express as px
df=pd.read_csv('/content/winequalityN.csv')
df.head(30)
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# 3   white            7.2              0.23         0.32            8.50
# 4   white            7.2              0.23         0.32            8.50
# 5   white            8.1              0.28         0.40            6.90
# 6   white            6.2              0.32         0.16            7.00
# 7   white            7.0              0.27         0.36           20.70
# 8   white            6.3              0.30         0.34            1.60
# 9   white            8.1              0.22         0.43            1.50
# 10  white            8.1              0.27         0.41            1.45
# 11  white            8.6              0.23         0.40            4.20
# ...

# %%
plt.title('BAR CHART')
plt.bar(df['residual sugar'],df['type'],color="violet")
# Out:
# <BarContainer object of 6497 artists>

# %%
plt.title('HISTOGRAM')
plt.hist(df['total sulfur dioxide'],bins=20)
# Out:
# (array([5.750e+02, 5.130e+02, 3.930e+02, 5.860e+02, 9.920e+02, 1.057e+03,
#         8.270e+02, 6.870e+02, 4.900e+02, 2.310e+02, 1.050e+02, 2.900e+01,
#         4.000e+00, 4.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([  6. ,  27.7,  49.4,  71.1,  92.8, 114.5, 136.2, 157.9, 179.6,
#         201.3, 223. , 244.7, 266.4, 288.1, 309.8, 331.5, 353.2, 374.9,
#         396.6, 418.3, 440. ]),
#  <a list of 20 Patch objects>)

# %%
plt.step(df['sulphates'],df['pH'])

# %%
plt.title('SCATTER PLOT')
plt.scatter(df['citric acid'],df['density'])

# %%
plt.title('STACKPLOT')
plt.stackplot(df['free sulfur dioxide'],df['quality'])

# %%
plt.title('LOLLIPOP CHART')
plt.stem(df['chlorides'],df['pH'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
df1=df.head(5)
label=df1['quality']
x=df1['fixed acidity']
plt.pie(x,labels=label)
plt.title('PIE CHART')
# Out:
# Text(0.5, 1.0, 'PIE CHART')
